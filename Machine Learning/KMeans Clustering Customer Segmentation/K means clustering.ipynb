# %% [markdown]
# ### Unsupervised algorithm

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data=make_blobs(n_samples=10000000,n_features=2,centers=10,cluster_std=1.8,random_state=101)

# %%
data
# Out:
# (array([[ 2.70520867,  6.92120364],
#         [ 4.54713185, -7.48970014],
#         [-1.17411276, -0.56359156],
#         ...,
#         [ 5.58024669, -5.3374151 ],
#         [-6.14874188,  8.88880858],
#         [-8.48406733, -5.72397358]]),
#  array([2, 4, 0, ..., 9, 6, 1]))

# %% [markdown]
# ### Visualize Data

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
data[0][:,0]
# Out:
# array([ 2.70520867,  4.54713185, -1.17411276, ...,  5.58024669,
#        -6.14874188, -8.48406733])

# %%
data[0][:,1]
# Out:
# array([ 6.92120364, -7.48970014, -0.56359156, ..., -5.3374151 ,
#         8.88880858, -5.72397358])

# %% [markdown]
# ### Creating the clusters

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(n_clusters=4)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 1.83976573,  3.96470745],
#        [-9.24438923, -5.89197867],
#        [ 5.10862428, -4.95115868],
#        [-6.2409237 ,  5.34519445]])

# %%
kmeans.labels_
# Out:
# array([2, 0, 0, ..., 2, 3, 1])

# %%
f, (ax1,ax2)=plt.subplots(1,2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')
ax2.set_title('Original')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')
