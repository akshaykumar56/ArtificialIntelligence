# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('cars_clus.csv')

# %%
data
# Out:
#        manufact    model   sales  resale  type  price  engine_s  horsepow  \
# 0         Acura  Integra  16.919  16.360     0  21.50       1.8       140
# 1         Acura       TL  39.384  19.875     0  28.40       3.2       225
# 2         Acura       RL   8.588  29.725     0  42.00       3.5       210
# 3          Audi       A4  20.397  22.255     0  23.99       1.8       150
# 4          Audi       A6  18.780  23.555     0  33.95       2.8       200
# ..          ...      ...     ...     ...   ...    ...       ...       ...
# 112  Volkswagen     Golf   9.761  11.425     0  14.90       2.0       115
# 113  Volkswagen    Jetta  83.721  13.240     0  16.70       2.0       115
# 114  Volkswagen   Passat  51.102  16.725     0  21.20       1.8       150
# 115  Volkswagen   Cabrio   9.569  16.575     0  19.99       2.0       115
# 116  Volkswagen      GTI   5.596  13.760     0  17.50       2.0       115
#
#      wheelbas  width  length  curb_wgt  fuel_cap   mpg  lnsales  partition
# ...

# %%
data.describe()
# Out:
#             sales      resale        type       price    engine_s    horsepow  \
# count  117.000000  117.000000  117.000000  117.000000  117.000000  117.000000
# mean    59.112316   18.031538    0.247863   25.969487    3.048718  181.282051
# std     75.058933   11.605632    0.433629   14.149699    1.055169   58.591786
# min      0.110000    5.160000    0.000000    9.235000    1.000000   55.000000
# 25%     16.767000   11.240000    0.000000   16.980000    2.200000  140.000000
# 50%     32.299000   14.010000    0.000000   21.665000    3.000000  175.000000
# 75%     76.029000   19.875000    0.000000   29.465000    3.800000  210.000000
# max    540.561000   67.550000    1.000000   82.600000    8.000000  450.000000
#
#          wheelbas       width      length    curb_wgt    fuel_cap         mpg  \
# count  117.000000  117.000000  117.000000  117.000000  117.000000  117.000000
# mean   107.326496   71.189744  187.717949    3.324051   17.812821   24.117949
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   manufact   117 non-null    object
#  1   model      117 non-null    object
#  2   sales      117 non-null    float64
#  3   resale     117 non-null    float64
#  4   type       117 non-null    int64
#  5   price      117 non-null    float64
#  6   engine_s   117 non-null    float64
#  7   horsepow   117 non-null    int64
#  8   wheelbas   117 non-null    float64
#  9   width      117 non-null    float64
#  10  length     117 non-null    float64
#  11  curb_wgt   117 non-null    float64
#  12  fuel_cap   117 non-null    float64
#  13  mpg        117 non-null    float64
#  14  lnsales    117 non-null    float64
#  15  partition  117 non-null    int64
# dtypes: float64(11), int64(3), object(2)
# memory usage: 14.8+ KB

# %%
X=data[['sales','resale','type','engine_s','horsepow','wheelbas','width','length','curb_wgt','fuel_cap','mpg','lnsales','partition']]
y=data['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=104)

# %%
X_train
# Out:
#        sales  resale  type  engine_s  horsepow  wheelbas  width  length  \
# 111    9.835  34.080     1       4.7       230     112.2   76.4   192.5
# 42   276.747  16.640     1       4.0       210     111.6   70.2   190.7
# 39    35.068   8.835     0       2.5       170     106.5   69.1   184.6
# 5      1.380  39.000     0       4.2       310     113.0   74.0   198.2
# 18    42.593  11.525     0       3.4       180     110.5   72.7   197.9
# ..       ...     ...   ...       ...       ...       ...    ...     ...
# 38   113.369  12.760     0       3.8       190     101.3   73.1   183.2
# 14    11.185  18.225     0       3.0       200     107.4   70.3   194.8
# 89    24.361  15.240     1       3.4       185     120.0   72.2   201.4
# 65    42.541  10.395     0       2.4       154     100.8   68.9   175.4
# 69    11.337  19.125     1       3.5       200     107.3   69.9   186.6
#
#      curb_wgt  fuel_cap   mpg  lnsales  partition
# 111     5.115      25.4  15.0    2.286          0
# ...

# %%
y_train
# Out:
# 111    51.728
# 42     31.930
# 39     17.035
# 5      62.000
# 18     19.390
#         ...
# 38     21.560
# 14     31.010
# 89     25.345
# 65     19.047
# 69     31.807
# Name: price, Length: 70, dtype: float64

# %%
X_test
# Out:
#        sales  resale  type  engine_s  horsepow  wheelbas  width  length  \
# 73    67.956  11.030     0       3.0       153     108.5   73.0   199.7
# 30    71.186  10.185     0       2.5       168     108.0   71.0   186.0
# 46   540.561  15.075     1       4.6       220     138.5   79.1   224.5
# 35   111.313  11.260     1       2.5       120     131.0   71.5   215.0
# 2      8.588  29.725     0       3.5       210     114.6   71.4   196.6
# 23     7.854  12.360     0       2.5       163     103.7   69.7   190.9
# 41    63.403  14.210     0       4.6       200     114.7   78.2   212.0
# 92    24.155  12.025     1       2.4       150     113.3   76.8   186.3
# 22    21.855   5.160     0       1.0        55      93.1   62.6   149.4
# 7     17.527  36.125     0       2.8       193     111.4   70.9   188.0
# 80     3.311  58.600     0       5.0       302      99.0   71.3   177.1
# 94   131.097  10.290     0       3.4       175     107.0   70.4   186.3
# ...

# %%
y_test
# Out:
# 73     19.035
# 30     20.230
# 46     26.935
# 35     16.980
# 2      42.000
# 23     19.840
# 41     22.195
# 92     18.850
# 22      9.235
# 7      38.900
# 80     82.600
# 94     19.720
# 75     27.560
# 84     26.399
# 54     14.999
# 70     22.527
# 50     26.600
# 114    21.200
# 68     25.450
# 105    17.518
# 115    19.990
# 86     18.145
# 51     26.000
# 56     14.460
# 44     36.135
# 15     13.260
# 109    16.888
# 20     45.705
# 0      21.500
# 32     19.460
# 66     17.357
# 108    11.528
# 27     28.340
# 10     31.965
# 16     16.535
# 61     54.005
# 83     26.249
# 106    25.545
# 21     13.960
# 57     21.620
# 72     16.540
# 40     17.885
# 74     22.605
# 97     23.755
# 45     12.050
# 71     16.240
# 34     18.575
# Name: price, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lg=LinearRegression()

# %%
lg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
data.columns
# Out:
# Index(['manufact', 'model', 'sales', 'resale', 'type', 'price', 'engine_s',
#        'horsepow', 'wheelbas', 'width', 'length', 'curb_wgt', 'fuel_cap',
#        'mpg', 'lnsales', 'partition'],
#       dtype='object')

# %%
data.head()
# Out:
#   manufact    model   sales  resale  type  price  engine_s  horsepow  \
# 0    Acura  Integra  16.919  16.360     0  21.50       1.8       140
# 1    Acura       TL  39.384  19.875     0  28.40       3.2       225
# 2    Acura       RL   8.588  29.725     0  42.00       3.5       210
# 3     Audi       A4  20.397  22.255     0  23.99       1.8       150
# 4     Audi       A6  18.780  23.555     0  33.95       2.8       200
#
#    wheelbas  width  length  curb_wgt  fuel_cap   mpg  lnsales  partition
# 0     101.2   67.3   172.4     2.639      13.2  28.0    2.828          0
# 1     108.1   70.3   192.9     3.517      17.2  25.0    3.673          0
# 2     114.6   71.4   196.6     3.850      18.0  22.0    2.150          0
# 3     102.6   68.2   178.0     2.998      16.4  27.0    3.015          0
# 4     108.7   76.1   192.0     3.561      18.5  22.0    2.933          0

# %%
a=float(input("Enter the value of sales: "))
b=float(input("Enter the value of resale: "))
c=float(input("Enter the value of type: "))
d=float(input("Enter the value of engine_s: "))
e=float(input("Enter the value of horsepow: "))
f=float(input("Enter the value of wheelbas: "))
g=float(input("Enter the value of width: "))
h=float(input("Enter the value of length: "))
i=float(input("Enter the value of curb_wgt: "))
j=float(input("Enter the value of fuel_cap: "))
k=float(input("Enter the value of mpg: "))
l=float(input("Enter the value of lnsales: "))
m=float(input("Enter the value of partition: "))
d=np.array([[a,b,c,d,e,f,g,h,i,j,k,l,m]])
pred=lg.predict(d)
pred
# Out:
# Enter the value of sales: 16.919
# Enter the value of resale: 16.360
# Enter the value of type: 0
# Enter the value of engine_s: 1.8
# Enter the value of horsepow: 140
# Enter the value of wheelbas: 101.2
# Enter the value of width: 67.3
# Enter the value of length: 172.4
# Enter the value of curb_wgt: 2.639
# Enter the value of fuel_cap: 13.2
# Enter the value of mpg: 28.0
# Enter the value of lnsales: 2.828
# Enter the value of partition: 0
# C:\Users\kshyk\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([20.14253107])

# %%
a=float(input("Enter the value of sales: "))
b=float(input("Enter the value of resale: "))
c=float(input("Enter the value of type: "))
d=float(input("Enter the value of engine_s: "))
e=float(input("Enter the value of horsepow: "))
f=float(input("Enter the value of wheelbas: "))
g=float(input("Enter the value of width: "))
h=float(input("Enter the value of length: "))
i=float(input("Enter the value of curb_wgt: "))
j=float(input("Enter the value of fuel_cap: "))
k=float(input("Enter the value of mpg: "))
l=float(input("Enter the value of lnsales: "))
m=float(input("Enter the value of partition: "))
d=np.array([[a,b,c,d,e,f,g,h,i,j,k,l,m]])
pred=lg.predict(d)
pred
# Out:
# Enter the value of sales: 16
# Enter the value of resale: 16
# Enter the value of type: 0
# Enter the value of engine_s: 140
# Enter the value of horsepow: 101
# Enter the value of wheelbas: 67
# Enter the value of width: 172
# Enter the value of length: 3
# Enter the value of curb_wgt: 18
# Enter the value of fuel_cap: 27
# Enter the value of mpg: 3
# Enter the value of lnsales: 0
# Enter the value of partition: 0
# C:\Users\kshyk\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([163.43822633])
